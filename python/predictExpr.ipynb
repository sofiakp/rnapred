# %%
# %matplotlib inline
import rnapredCV
from rnapredCV import *

# Make predictions on Roadmap data based 
feat_mat_dir = '/home/sofiakp/scg3_lab/users/sofiakp/roadmap/rnapred/feat_mat/'
model_dir = '/home/sofiakp/projects/roadmap/rnapred/feat_mat/cv/rf/t200_s100_t200_s5/'
out_dir = os.path.join(model_dir, 'pred')

if not os.path.isdir(out_dir):
    os.mkdir(out_dir)

# Roadmap metadata
roadmap_meta = '/media/SeagateStanford/nobackup/roadmap/jul2013.roadmapData.qc.Unique_Epigenomes.Stats_v2.tsv'
meta = pd.read_csv(roadmap_meta, sep = '\t', header = 0, na_values = 'Unknown')
# Remove the two additional header lines
meta = meta.iloc[2:,:]
ids = np.array(meta['NEW EID'])
names = np.array(meta.iloc[:, 16])

# Read the existing data
expr_file = '/home/sofiakp/projects/roadmap/rna/Dec13/medusaInputs/noDupGenes/57epigenomes_mergedPc_expr.txt'
gene_name_file = '/home/sofiakp/projects/roadmap/rna/Dec13/medusaInputs/noDupGenes/57epigenomes_mergedPc_genes.txt'
expt_name_file = '/home/sofiakp/projects/roadmap/rna/Dec13/medusaInputs/noDupGenes/57epigenomes_mergedPc_exptnames.txt'

expr = np.arcsinh(np.loadtxt(expr_file, delimiter = '\t'))
with open(expt_name_file, 'r') as infile:
    expt_names = np.array([line.strip().split('_')[0] for line in infile.readlines()])
is_imputed = [False for ex in expt_names]
long_names = ['_'.join([ex, str(names[np.argwhere(ids == ex)[0][0]])]) for ex in expt_names]

with open(gene_name_file, 'r') as infile:
    gene_names = np.array([line.strip().split()[0] for line in infile.readlines()])
    
model = read_model(os.path.join(model_dir, 'merged_model.pkl'))
model.set_njobs(6)

with open(os.path.join(feat_mat_dir, 'all_expt_names.txt'), 'r') as infile:
    for line in infile:
        ex = line.strip()
        feat_mat_file = os.path.join(feat_mat_dir, ex + '_feat_mat.npz')
        if ex in expt_names or not os.path.exists(feat_mat_file):
            continue 
        long_names.append('_'.join([ex, str(names[np.argwhere(ids == ex)[0][0]])]))
        feat, y, feat_names, tmp_gene_names = read_feat_mat(feat_mat_file)
        is_imputed.append(True)
        assert(y is None)
        y = model.predict(feat)
        expr = np.concatenate((expr, np.reshape(y, (y.size, 1))), axis = 1)
        assert(all(g[0] == g[1] for g in zip(gene_names, tmp_gene_names)))

# %%
np.savetxt(os.path.join(out_dir, 'imputed_expr.txt'), expr, fmt = '%.4f', delimiter = '\t')
with open(os.path.join(out_dir, 'imputed_exptnames.txt'), 'w') as outfile:
    for ex in long_names:
        outfile.write(ex + '\n')
np.savetxt(os.path.join(out_dir, 'imputed_is_imputed.txt'), np.array(is_imputed), fmt = '%d', delimiter = '\t')
with open(os.path.join(out_dir, 'imputed_genes.txt'), 'w') as outfile:
    for g in gene_names:
        outfile.write(g + '\n')

# %%
zip(long_names, is_imputed)
# Out:
# [('E003_H1_Cell_Line', False),
#  ('E004_H1_BMP4_Derived_Mesendoderm_Cultured_Cells', False),
#  ('E005_H1_BMP4_Derived_Trophoblast_Cultured_Cells', False),
#  ('E006_H1_Derived_Mesenchymal_Stem_Cells', False),
#  ('E007_H1_Derived_Neuronal_Progenitor_Cultured_Cells', False),
#  ('E011_hESC_Derived_CD184+_Endoderm_Cultured_Cells', False),
#  ('E012_hESC_Derived_CD56+_Ectoderm_Cultured_Cells', False),
#  ('E013_hESC_Derived_CD56+_Mesoderm_Cultured_Cells', False),
#  ('E016_HUES64_Cell_Line', False),
#  ('E024_4star', False),
#  ('E027_Breast_Myoepithelial_Cells', False),
#  ('E028_Breast_vHMEC', False),
#  ('E037_CD4_Memory_Primary_Cells', False),
#  ('E038_CD4_Naive_Primary_Cells', False),
#  ('E047_CD8_Naive_Primary_Cells', False),
#  ('E050_Mobilized_CD34_Primary_Cells_Female', False),
#  ('E053_Neurosphere_Cultured_Cells_Cortex_Derived', False),
#  ('E054_Neurosphere_Cultured_Cells_Ganglionic_Eminence_Derived', False),
#  ('E055_Penis_Foreskin_Fibroblast_Primary_Cells_skin01', False),
#  ('E056_Penis_Foreskin_Fibroblast_Primary_Cells_skin02', False),
#  ('E057_Penis_Foreskin_Keratinocyte_Primary_Cells_skin02', False),
#  ('E058_Penis_Foreskin_Keratinocyte_Primary_Cells_skin03', False),
#  ('E059_Penis_Foreskin_Melanocyte_Primary_Cells_skin01', False),
#  ('E061_Penis_Foreskin_Melanocyte_Primary_Cells_skin03', False),
#  ('E062_Peripheral_Blood_Mononuclear_Primary_Cells', False),
#  ('E065_Aorta', False),
#  ('E066_Adult_Liver', False),
#  ('E070_Brain_Germinal_Matrix', False),
#  ('E071_Brain_Hippocampus_Middle', False),
#  ('E079_Esophagus', False),
#  ('E082_Fetal_Brain_Female', False),
#  ('E084_Fetal_Intestine_Large', False),
#  ('E085_Fetal_Intestine_Small', False),
#  ('E087_Pancreatic_Islets', False),
#  ('E094_Gastric', False),
#  ('E095_Left_Ventricle', False),
#  ('E096_Lung', False),
#  ('E097_Ovary', False),
#  ('E098_Pancreas', False),
#  ('E100_Psoas_Muscle', False),
#  ('E104_Right_Atrium', False),
#  ('E105_Right_Ventricle', False),
#  ('E106_Sigmoid_Colon', False),
#  ('E109_Small_Intestine', False),
#  ('E112_Thymus', False),
#  ('E113_Spleen', False),
#  ('E114_A549_EtOH_0.02pct_Lung_Carcinoma', False),
#  ('E116_GM12878_Lymphoblastoid', False),
#  ('E117_HeLa-S3_Cervical_Carcinoma', False),
#  ('E118_HepG2_Hepatocellular_Carcinoma', False),
#  ('E119_HMEC_Mammary_Epithelial', False),
#  ('E120_HSMM_Skeletal_Muscle_Myoblasts', False),
#  ('E122_HUVEC_Umbilical_Vein_Endothelial_Cells', False),
#  ('E123_K562_Leukemia', False),
#  ('E127_NHEK-Epidermal_Keratinocytes', False),
#  ('E128_NHLF_Lung_Fibroblasts', False),
#  ('E017_IMR90_Cell_Line', True),
#  ('E021_iPS_DF_6.9_Cell_Line', True),
#  ('E022_iPS_DF_19.11_Cell_Line', True),
#  ('E029_CD14_Primary_Cells', True),
#  ('E032_CD19_Primary_Cells_Peripheral_UW', True),
#  ('E033_CD3_Primary_Cells_Cord_BI', True),
#  ('E034_CD3_Primary_Cells_Peripheral_UW', True),
#  ('E035_CD34_Primary_Cells', True),
#  ('E051_Mobilized_CD34_Primary_Cells_Male', True),
#  ('E080_Fetal_Adrenal_Gland', True),
#  ('E081_Fetal_Brain_Male', True),
#  ('E083_Fetal_Heart', True),
#  ('E086_Fetal_Kidney', True),
#  ('E088_Fetal_Lung', True),
#  ('E090_Fetal_Muscle_Leg', True),
#  ('E093_Fetal_Thymus', True),
#  ('E121_HSMMtube_Skeletal_Muscle_Myotubes_Derived_from_HSMM', True),
#  ('E124_Monocytes-CD14+_RO01746', True),
#  ('E125_NH-A_Astrocytes', True),
#  ('E126_NHDF-Ad_Adult_Dermal_Fibroblasts', True),
#  ('E129_Osteoblasts', True)]
